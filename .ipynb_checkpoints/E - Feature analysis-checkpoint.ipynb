# %%
% matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json
import time
from time import strftime
from datetime import datetime
import matplotlib 
from IPython.core.display import clear_output
from sklearn.externals import joblib
import seaborn as sns
import re
#import nlkt

# %%
bins=np.arange(0,50000+1000,1000)

# %%
bins
# Out:
# array([    0,  1000,  2000,  3000,  4000,  5000,  6000,  7000,  8000,
#         9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000,
#        18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000,
#        27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000,
#        36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000,
#        45000, 46000, 47000, 48000, 49000, 50000])

# %%
features = joblib.load('/Users/natacha/Documents/Insight/Final Features/Final_Features_{}-{}.pkl'.format(
            0,
            999))

features=features.drop(columns=["index0","index1"])

for i in range(len(bins)-1):
    
    star_ID = bins[i]
    fin_ID = bins[i+1]
    
    ff = joblib.load('/Users/natacha/Documents/Insight/Final Features/Final_Features_{}-{}.pkl'.format(
            star_ID,
            fin_ID-1))
    ff=ff.drop(columns=["index0","index1"])
    
    features = pd.concat([features,ff])

# %%
features.head()
# Out:
#       goal  founded_bool  code  num_videos  num_pics  num_perks  num_links  \
# 0   5000.0          True     8         0.0      17.0       15.0        0.0
# 1  25000.0         False    13         0.0       0.0        6.0        0.0
# 2  20000.0          True     6         0.0       8.0       20.0       11.0
# 3  15000.0          True    13         1.0      11.0        4.0        0.0
# 4   5000.0          True    10         0.0       7.0       12.0        2.0
#
#    num_of_sent_about  num_of_sent_risk  num_of_sent_perks      ...       \
# 0               70.0              13.0               72.0      ...
# 1               36.0               6.0               20.0      ...
# 2               43.0               6.0               29.0      ...
# 3               39.0               3.0                9.0      ...
# 4               55.0               5.0               36.0      ...
#
#    freq_italic_R  num_of_exclamation_A  num_of_exclamation_R  \
# ...

# %%
features.tail()
# Out:
#           goal  founded_bool  code  num_videos  num_pics  num_perks  \
# 49995   3500.0         False     6         0.0       0.0        6.0
# 49996  25000.0         False     8         0.0       0.0        3.0
# 49997   1700.0         False     7         0.0       0.0        4.0
# 49998  50000.0         False     9         0.0       0.0        6.0
# 49999    250.0          True    12         0.0       1.0        7.0
#
#        num_links  num_of_sent_about  num_of_sent_risk  num_of_sent_perks  \
# 49995        0.0                7.0               NaN                8.0
# 49996        0.0               12.0               5.0               11.0
# 49997        0.0               14.0               3.0                5.0
# 49998        0.0               14.0               8.0               14.0
# 49999        0.0                3.0               2.0                5.0
#
#            ...       freq_italic_R  num_of_exclamation_A  \
# ...

# %%
# Replace the nan's in each column by the mean of that column

features=features.apply(lambda x: x.fillna(x.mean()),axis=0);

# %%
features.columns
# Out:
# Index(['goal', 'founded_bool', 'code', 'num_videos', 'num_pics', 'num_perks',
#        'num_links', 'num_of_sent_about', 'num_of_sent_risk',
#        'num_of_sent_perks', 'num_of_words_about', 'num_of_words_risk',
#        'num_of_words_perks', 'freq_bold_A', 'freq_italic_A',
#        'num_of_exclamation_A', 'num_of_exclamation_R', 'num_of_exclamation_P',
#        'bool_A', 'bool_P', 'freq_pitch_A', 'freq_pitch_R', 'freq_pitch_P'],
#       dtype='object')

# %%
features.isnull().any()
# Out:
# goal                    False
# founded_bool            False
# code                    False
# num_videos              False
# num_pics                False
# num_perks               False
# num_links               False
# num_of_sent_about       False
# num_of_sent_risk        False
# num_of_sent_perks       False
# num_of_words_about      False
# num_of_words_risk       False
# num_of_words_perks      False
# freq_bold_A             False
# freq_bold_R             False
# freq_italic_A           False
# freq_italic_R           False
# num_of_exclamation_A    False
# num_of_exclamation_R    False
# num_of_exclamation_P    False
# bool_A                  False
# bool_P                  False
# bool_R                  False
# freq_pitch_A            False
# freq_pitch_R            False
# freq_pitch_P            False
# dtype: bool

# %%
features.keys()
# Out:
# Index(['goal', 'founded_bool', 'code', 'num_videos', 'num_pics', 'num_perks',
#        'num_links', 'num_of_sent_about', 'num_of_sent_risk',
#        'num_of_sent_perks', 'num_of_words_about', 'num_of_words_risk',
#        'num_of_words_perks', 'freq_bold_A', 'freq_bold_R', 'freq_italic_A',
#        'freq_italic_R', 'num_of_exclamation_A', 'num_of_exclamation_R',
#        'num_of_exclamation_P', 'bool_A', 'bool_P', 'bool_R', 'freq_pitch_A',
#        'freq_pitch_R', 'freq_pitch_P'],
#       dtype='object')

# %%
ag=features.groupby('code').founded_bool.value_counts().sort_index()
#ag_ample=features.groupby('category').founded_bool.value_counts().sort_index()
ag_price=features.groupby("code").goal.sum().sort_index()
ag.unstack()
# Out:
# founded_bool  False  True
# code
# 0              2642   2606
# 1               599   1627
# 2               948    624
# 3               193    727
# 4               687   1110
# 5              1326    929
# 6              3173   4096
# 7              2885   1655
# 8              1273   1802
# 9               842    243
# 10             2689   5248
# 11              857    769
# 12             1630   3345
# 13             3027   1595
# 14              481   1372

# %%
ag_price.sum()/1000000
# Out:
# 2126.81245674

# %%
ag.unstack().plot(kind='bar')
#ag_ample.unstack().plot(kind="bar")
#plt.savefig("bias.jpeg")

# %%
features.corr()
# Out:
#                           goal  founded_bool      code    num_videos  \
# goal                  1.000000     -0.030586 -0.000735  1.405296e-03
# founded_bool         -0.030586      1.000000  0.014415  4.224561e-03
# code                 -0.000735      0.014415  1.000000  6.070977e-02
# num_videos            0.001405      0.004225  0.060710  1.000000e+00
# num_pics             -0.004316      0.159392 -0.051785  2.809877e-01
# num_perks            -0.011694      0.302917 -0.042175  8.669473e-02
# num_links             0.009627      0.181922 -0.000246  6.697404e-02
# num_of_sent_about     0.006514      0.199637  0.038684  1.705807e-01
# num_of_sent_risk      0.001032      0.071790  0.035444  7.009723e-02
# num_of_sent_perks    -0.002899      0.171137 -0.034411  7.804854e-02
# num_of_words_about    0.007921      0.197174  0.047045  1.701810e-01
# num_of_words_risk     0.005214      0.074424  0.038661  6.956391e-02
# num_of_words_perks   -0.003340      0.216393 -0.027397  8.760985e-02
# ...

# %%
# Remove  the ones which all the values are the same

features.drop(columns=["freq_bold_R","freq_italic_R"],inplace=True)

# %%
features.corr()
# Out:
#                           goal  founded_bool      code    num_videos  \
# goal                  1.000000     -0.037347 -0.006841  3.056054e-06
# founded_bool         -0.037347      1.000000  0.018453  8.027827e-03
# code                 -0.006841      0.018453  1.000000  8.561570e-02
# num_videos            0.000003      0.008028  0.085616  1.000000e+00
# num_pics             -0.007265      0.155484 -0.053043  2.839198e-01
# num_perks            -0.025388      0.311941 -0.063262  7.332596e-02
# num_links             0.054924      0.189286  0.011471  9.697975e-02
# num_of_sent_about    -0.009765      0.190252  0.031901  1.675689e-01
# num_of_sent_risk      0.011377      0.061851  0.032046  3.778169e-02
# num_of_sent_perks    -0.007345      0.171729 -0.081040  7.394987e-02
# num_of_words_about   -0.001880      0.191042  0.049085  1.471502e-01
# num_of_words_risk     0.032773      0.071782  0.036128  4.427222e-02
# num_of_words_perks   -0.009112      0.205328 -0.070191  7.746922e-02
# ...

# %%
plt.bar(features.keys(),features.corr()["founded_bool"])
# Out:
# <BarContainer object of 23 artists>

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(14, 10)

sns.heatmap(features.corr())

# %%
features_founded=features[features["founded_bool"]==True].drop(columns=["founded_bool"])
features_UNfounded=features[features["founded_bool"]==False].drop(columns=["founded_bool"])

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(14, 10)

sns.heatmap(features_founded.corr())

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(14, 10)

sns.heatmap(features_UNfounded.corr())

# %%
features=features.drop(columns=["bool_R"])
features_founded=features_founded.drop(columns=["bool_R"])
features_UNfounded=features_UNfounded.drop(columns=["bool_R"])

# %% [markdown]
# # BY eye comparison by class of different features

# %%
sns.distplot(features_UNfounded['num_videos'])
sns.distplot(features_founded['num_videos'])
# Out:
# /Users/natacha/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/natacha/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(features_UNfounded['num_videos'],label="UF",color="r")
sns.kdeplot(features_founded['num_videos'],label="F",color="g")

# %%
sns.kdeplot(features_UNfounded['num_pics'],label="UF",color="r",shade=True)
sns.kdeplot(features_founded['num_pics'],label="F",color="g",shade=True)

# %%
sns.kdeplot(features_UNfounded['num_perks'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['num_perks'],label="F",color="g",shade=True)

# %%
sns.kdeplot(features_UNfounded['num_links'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['num_links'],label="F",color="g",shade=True)

# %%
sns.kdeplot(features_UNfounded['num_links'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['num_links'],label="F",color="g",shade=True)

# %%
sns.kdeplot(features_UNfounded['num_of_sent_about'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['num_of_sent_about'],label="F",color="g",shade=True)

# %%
plt.figure()
sns.kdeplot(features_UNfounded['num_of_sent_risk'],label="UF",color="r",shade="True")
#sns.kdeplot(features_founded['num_of_sent_risk'],label="F",color="g",shade=True)
plt.xlim(0,100)
# Out:
# (0, 100)

# %%
plt.figure()
sns.kdeplot(features_founded['num_of_sent_risk'],label="F",color="g",shade=True)
plt.xlim(0,100)
# Out:
# (0, 100)

# %%
sns.kdeplot(features_UNfounded['num_of_words_about'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['num_of_words_about'],label="F",color="g",shade=True)

# %%
plt.figure()
sns.kdeplot(features_UNfounded['num_of_words_risk'],label="UF",color="r",shade="True")
#sns.kdeplot(features_founded['num_of_words_risk'],label="F",color="g",shade=True)
plt.xlim(0,1000)
# Out:
# (0, 1000)

# %%
plt.figure()
sns.kdeplot(features_founded['num_of_words_risk'],label="F",color="g",shade=True)
plt.xlim(0,1000)
# Out:
# (0, 1000)

# %%
sns.kdeplot(features_UNfounded['bool_P'],label="UF",color="r",shade="True")
#sns.kdeplot(features_founded['bool_P'],label="F",color="g",shade=True)

# %%
sns.kdeplot(features_founded['bool_P'],label="F",color="g",shade=True)

# %%
sns.kdeplot(features_UNfounded['freq_pitch_A'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['freq_pitch_A'],label="F",color="g",shade=True)

# %%
plt.figure()
sns.kdeplot(features_UNfounded['freq_bold_A'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['freq_bold_A'],label="F",color="g",shade=True)
plt.xlim(0,200)
# Out:
# (0, 200)

# %%
sns.kdeplot(features_UNfounded['freq_pitch_R'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['freq_pitch_R'],label="F",color="g",shade=True)

# %%
sns.kdeplot(features_UNfounded['freq_pitch_R'],label="UF",color="r",shade="True")
sns.kdeplot(features_founded['freq_pitch_R'],label="F",color="g",shade=True)

# %%
plt.hist(features_UNfounded['freq_pitch_A'],normed=1);
# Out:
# /Users/natacha/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.hist(features_founded['freq_pitch_A'],normed=1);
# Out:
# /Users/natacha/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
features_founded['freq_pitch_A'].mean()
# Out:
# 6.577327961358426

# %%
features_UNfounded['freq_pitch_A'].mean()
# Out:
# 6.475923753476067

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

# %%
target=features["founded_bool"]

# %%
x_test.keys()
# Out:
# Index(['goal', 'code', 'num_videos', 'num_pics', 'num_perks', 'num_links',
#        'num_of_sent_about', 'num_of_sent_risk', 'num_of_sent_perks',
#        'num_of_words_about', 'num_of_words_risk', 'num_of_words_perks',
#        'freq_bold_A', 'freq_italic_A', 'num_of_exclamation_A',
#        'num_of_exclamation_R', 'num_of_exclamation_P', 'bool_A', 'bool_P',
#        'freq_pitch_A', 'freq_pitch_R', 'freq_pitch_P'],
#       dtype='object')

# %%
data=features.drop(columns=["founded_bool"])

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.25, random_state=0)

# %%
logisticRegr = LogisticRegression()

# %%
logisticRegr.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
# 0.7350588235294118

# %%
logisticRegr.coef_
# Out:
# array([[-3.36e-05,  1.12e-02, -2.75e-03,  4.38e-03,  9.80e-02,  6.48e-02,
#          1.48e-03, -5.17e-03, -7.85e-03,  1.63e-04, -1.33e-04,  5.10e-04,
#          1.72e-03,  8.71e-03,  2.87e-02,  6.18e-03,  5.22e-03, -6.27e-03,
#         -6.27e-03, -2.06e-02, -2.14e-02, -3.43e-02]])

# %%
score = logisticRegr.score(x_train, y_train)
print(score)
# Out:
# 0.7263267973856209

# %%
predictions=logisticRegr.predict(x_test)

# %%
prob=logisticRegr.predict_proba(x_test)
# Out:
# /Users/natacha/anaconda/lib/python3.5/site-packages/sklearn/linear_model/base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)

# %%
logisticRegr.classes_
# Out:
# array([False,  True])

# %%
prob
# Out:
# array([[0.27, 0.73],
#        [0.44, 0.56],
#        [0.19, 0.81],
#        ...,
#        [0.29, 0.71],
#        [0.99, 0.01],
#        [0.46, 0.54]])

# %%
features.describe()
# Out:
#                goal          code    num_videos      num_pics     num_perks  \
# count  5.100000e+04  51000.000000  51000.000000  51000.000000  51000.000000
# mean   4.170221e+04      7.437961      0.074913      4.970424      8.248988
# std    1.168504e+06      4.201852      0.461257      9.232392      6.027268
# min    1.000000e-02      0.000000      0.000000      0.000000      0.000000
# 25%    1.800000e+03      5.000000      0.000000      0.000000      4.000000
# 50%    5.000000e+03      7.000000      0.000000      0.000000      7.000000
# 75%    1.250000e+04     11.000000      0.000000      6.000000     11.000000
# max    1.000000e+08     14.000000     20.000000    153.000000    227.000000
#
#           num_links  num_of_sent_about  num_of_sent_risk  num_of_sent_perks  \
# count  51000.000000       51000.000000      51000.000000       51000.000000
# mean       2.282416          28.485438          5.892712          18.668298
# ...

# %%
x_test.keys()
# Out:
# Index(['num_videos', 'num_pics', 'num_perks', 'num_links', 'num_of_sent_about',
#        'num_of_sent_risk', 'num_of_sent_perks', 'num_of_words_about',
#        'num_of_words_risk', 'num_of_words_perks', 'freq_bold_A',
#        'freq_italic_A', 'num_of_exclamation_A', 'num_of_exclamation_R',
#        'num_of_exclamation_P', 'bool_A', 'bool_P', 'freq_pitch_A',
#        'freq_pitch_R', 'freq_pitch_P'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
>>> from sklearn import metrics

# %% [markdown]
# rf = RandomForestClassifier(n_estimators = 20, random_state = 42,max_depth=10)

# %%
rf = RandomForestClassifier(n_estimators = 20, random_state = 42,max_depth=10)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
predictions = rf.predict(x_test)

# %%
predictions[0]
# Out:
# array([0.34, 0.66])

# %%
rf.classes_
# Out:
# array([False,  True])

# %%
predictions
# Out:
# array([ True, False,  True, ...,  True, False,  True])

# %%
score = rf.score(x_test, y_test)
print(score)
# Out:
# 0.764078431372549

# %%
score = rf.score(x_train, y_train)
print(score)
# Out:
# 0.8144575163398693

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#       False       0.80      0.64      0.72      5876
#        True       0.74      0.87      0.80      6874
#
# avg / total       0.77      0.76      0.76     12750

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#       False       0.75      0.61      0.67      5876
#        True       0.71      0.83      0.77      6874
#
# avg / total       0.73      0.73      0.72     12750

# %%
fpr,tpr,_=roc_curve(y_test,predictions)
auc=metrics.auc(fpr,tpr)

# %%
roc_curve?

# %%
roc_curve(y_test,predictions)
# Out:
# (array([0.  , 0.36, 1.  ]), array([0.  , 0.87, 1.  ]), array([2, 1, 0]))

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve, AUC={}'.format(auc) )
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
rf.predict_proba(x_test)
# Out:
# array([[0.309     , 0.691     ],
#        [0.483     , 0.517     ],
#        [0.224     , 0.776     ],
#        ...,
#        [0.27944086, 0.72055914],
#        [0.789     , 0.211     ],
#        [0.409     , 0.591     ]])

# %%
from sklearn.tree import export_graphviz
import pydot

# %%
tree = rf.estimators_[5]

# %%
export_graphviz(tree, out_file = 'tree.dot', feature_names = x_test.keys(), rounded = True, precision = 1)

# %%
(graph, ) = pydot.graph_from_dot_file('tree.dot')

# %%
graph.write_png('tree.png');

# %%
importances = list(rf.feature_importances_)

# %%
feature_list = list(x_test.columns)

# %%
feature_list;

# %%
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# %%
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# %%
[print('Variable: {:25} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: num_perks                 Importance: 0.18
# Variable: num_of_words_perks        Importance: 0.12
# Variable: num_of_exclamation_R      Importance: 0.11
# Variable: num_links                 Importance: 0.08
# Variable: code                      Importance: 0.06
# Variable: num_of_words_about        Importance: 0.06
# Variable: num_of_words_risk         Importance: 0.06
# Variable: freq_bold_A               Importance: 0.06
# Variable: num_of_exclamation_P      Importance: 0.05
# Variable: freq_pitch_R              Importance: 0.05
# Variable: freq_italic_A             Importance: 0.04
# Variable: num_of_exclamation_A      Importance: 0.04
# Variable: num_pics                  Importance: 0.03
# Variable: freq_pitch_A              Importance: 0.03
# Variable: freq_pitch_P              Importance: 0.03
# Variable: num_videos                Importance: 0.01
# Variable: bool_A                    Importance: 0.0
# Variable: bool_P                    Importance: 0.0

# %%
j=0
for i in range(len(feature_importances)):
    print(feature_importances[i])
    j+=feature_importances[i][1]
# Out:
# ('goal', 0.14)
# ('num_of_words_perks', 0.09)
# ('num_perks', 0.08)
# ('num_of_sent_perks', 0.06)
# ('num_of_words_about', 0.06)
# ('freq_pitch_A', 0.06)
# ('freq_pitch_P', 0.06)
# ('num_of_sent_about', 0.05)
# ('num_of_words_risk', 0.05)
# ('freq_pitch_R', 0.05)
# ('num_links', 0.04)
# ('freq_bold_A', 0.04)
# ('num_of_exclamation_A', 0.04)
# ('num_of_exclamation_P', 0.04)
# ('num_pics', 0.03)
# ('num_of_sent_risk', 0.03)
# ('freq_italic_A', 0.03)
# ('num_of_exclamation_R', 0.03)
# ('num_videos', 0.0)
# ('bool_A', 0.0)
# ('bool_P', 0.0)

# %%
plt.style.use('fivethirtyeight')
x_values = list(range(len(importances)))
plt.bar(x_values, importances, orientation = 'vertical')
plt.xticks(x_values, feature_list, rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import itertools


cnf_matrix = confusion_matrix(y_test, predictions)
np.set_printoptions(precision=2)

# %%
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=rf.classes_,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=rf.classes_, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[3870 2006]
#  [ 965 5909]]
# Normalized confusion matrix
# [[0.66 0.34]
#  [0.14 0.86]]

# %%
Re=cnf_matrix[0][0]/(cnf_matrix[0][0]+cnf_matrix[1][0])

# %%
Pre=cnf_matrix[0][0]/(cnf_matrix[0][0]+cnf_matrix[0][1])

# %%
Accu=(cnf_matrix[0][0]+cnf_matrix[1][1])/(sum(cnf_matrix).sum())

# %%
print("The Recall of the model is: {}, \n the precission is: {},\n the accuracy is: {} \n and the F-measure: {}.".format(Re,Pre,Accu,F_measure))
# Out:
# The Recall of the model is: 0.8004136504653567,
#  the precission is: 0.6586113002042205,
#  the accuracy is: 0.7669803921568628
#  and the F-measure: 0.7423920081398575.

# %%
F_measure=2*Re*Pre/(Re+Pre)

# %%
rf.score?

# %%
sum(cnf_matrix).sum()
# Out:
# 12750

# %%
cnf_matrix
# Out:
# array([[4013, 1863],
#        [ 922, 5952]])

# %%
from sklearn.metrics import roc_curve, auc

# %%
fpr,tpr,_=roc_curve(y_test,predictions)

# %%
>>> from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#       False       0.80      0.66      0.72      5876
#        True       0.75      0.86      0.80      6874
#
# avg / total       0.77      0.77      0.76     12750

# %%
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold

# %%
clf = RandomForestClassifier(
    n_estimators=50,
    criterion='gini',
    max_depth=15,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0.0,
    max_features='auto',
    max_leaf_nodes=None,
    min_impurity_decrease=0.0,
    min_impurity_split=None,
    bootstrap=True,
    oob_score=False,
    n_jobs=-1,
    random_state=0,
    verbose=0,
    warm_start=False,
    class_weight='balanced'
)

# %%
def plot_roc_curve(fprs, tprs):
    """Plot the Receiver Operating Characteristic from a list
    of true positive rates and false positive rates."""
    
    # Initialize useful lists + the plot axes.
    tprs_interp = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)
    f, ax = plt.subplots(figsize=(14,10))
    
    # Plot ROC for each K-Fold + compute AUC scores.
    for i, (fpr, tpr) in enumerate(zip(fprs, tprs)):
        tprs_interp.append(np.interp(mean_fpr, fpr, tpr))
        tprs_interp[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        ax.plot(fpr, tpr, lw=1, alpha=0.3,
                 label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))
        
    # Plot the luck line.
    plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
             label='Luck', alpha=.8)
    
    # Plot the mean ROC.
    mean_tpr = np.mean(tprs_interp, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
             label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)
    
    # Plot the standard deviation around the mean ROC.
    std_tpr = np.std(tprs_interp, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                     label=r'$\pm$ 1 std. dev.')
    
    # Fine tune and show the plot.
    ax.set_xlim([-0.05, 1.05])
    ax.set_ylim([-0.05, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic')
    ax.legend(loc="lower right")

    plt.show()
    return (f, ax)

def compute_roc_auc(index):
    y_predict = clf.predict_proba(data.iloc[index])[:,1]
    fpr, tpr, thresholds = roc_curve(target.iloc[index], y_predict)
    auc_score = auc(fpr, tpr)
    return fpr, tpr, auc_score

# %%
cv = StratifiedKFold(n_splits=10, random_state=123, shuffle=True)
results = pd.DataFrame(columns=['training_score', 'test_score'])
fprs, tprs, scores = [], [], []
    
for (train, test), i in zip(cv.split(data, target), range(10)):
    
    clf.fit(data.iloc[train], target.iloc[train])
    
    _, _, auc_score_train = compute_roc_auc(train)
    
    fpr, tpr, auc_score = compute_roc_auc(test)
    
    scores.append((auc_score_train, auc_score))
    
    fprs.append(fpr)
    tprs.append(tpr)

plot_roc_curve(fprs, tprs);
pd.DataFrame(scores, columns=['AUC Train', 'AUC Test'])
# Out:
#    AUC Train  AUC Test
# 0   0.984978  0.851831
# 1   0.985187  0.848942
# 2   0.985144  0.840542
# 3   0.984915  0.845422
# 4   0.985596  0.849182
# 5   0.985539  0.845888
# 6   0.985237  0.857157
# 7   0.985003  0.844877
# 8   0.984967  0.850599
# 9   0.985108  0.846519

# %%
x_test.keys()
# Out:
# Index(['goal', 'code', 'num_videos', 'num_pics', 'num_perks', 'num_links',
#        'num_of_sent_about', 'num_of_sent_risk', 'num_of_sent_perks',
#        'num_of_words_about', 'num_of_words_risk', 'num_of_words_perks',
#        'freq_bold_A', 'freq_italic_A', 'num_of_exclamation_A',
#        'num_of_exclamation_R', 'num_of_exclamation_P', 'bool_A', 'bool_P',
#        'freq_pitch_A', 'freq_pitch_R', 'freq_pitch_P'],
#       dtype='object')

# %%
len(data.keys())
# Out:
# 22

# %%
predictions=clf.predict(x_train)

# %%
score = clf.score(x_test, y_test)
print(score)
# Out:
# 0.9196078431372549

# %%
score = clf.score(x_train, y_train)
print(score)
# Out:
# 0.9209934640522875

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#       False       0.95      0.87      0.91      5876
#        True       0.90      0.96      0.93      6874
#
# avg / total       0.92      0.92      0.92     12750

# %%
print(classification_report(y_train, predictions))
# Out:
#              precision    recall  f1-score   support
#
#       False       0.94      0.88      0.91     17376
#        True       0.90      0.96      0.93     20874
#
# avg / total       0.92      0.92      0.92     38250

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#       False       0.95      0.87      0.91      5876
#        True       0.90      0.96      0.93      6874
#
# avg / total       0.92      0.92      0.92     12750

# %%
fpr,tpr,_=roc_curve(y_test,predictions)
auc=metrics.auc(fpr,tpr)

# %%
clf

# %%
roc_curve?

# %%
roc_curve(y_test,predictions)
# Out:
# (array([0.  , 0.13, 1.  ]), array([0.  , 0.96, 1.  ]), array([2, 1, 0]))

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve, AUC={}'.format(auc) )
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
joblib.dump(clf, 'trained_RF.pkl')
# Out:
# ['trained_RF.pkl']

# %%
clff=joblib.load("trained_RF.pkl")

# %%
clff.predict_proba(x_test)
# Out:
# array([[0.25, 0.75],
#        [0.61, 0.39],
#        [0.16, 0.84],
#        ...,
#        [0.16, 0.84],
#        [0.95, 0.05],
#        [0.51, 0.49]])

# %%
clff.predict(x_test)
# Out:
# array([ True, False,  True, ...,  True, False, False])

# %%
importances = list(clf.feature_importances_)
feature_list = list(x_test.columns)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:25} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: goal                      Importance: 0.15
# Variable: num_of_words_perks        Importance: 0.09
# Variable: num_perks                 Importance: 0.08
# Variable: num_of_words_about        Importance: 0.06
# Variable: num_links                 Importance: 0.05
# Variable: num_of_sent_perks         Importance: 0.05
# Variable: num_of_words_risk         Importance: 0.05
# Variable: code                      Importance: 0.04
# Variable: num_of_sent_about         Importance: 0.04
# Variable: freq_bold_A               Importance: 0.04
# Variable: num_of_exclamation_A      Importance: 0.04
# Variable: num_of_exclamation_R      Importance: 0.04
# Variable: num_of_exclamation_P      Importance: 0.04
# Variable: freq_pitch_A              Importance: 0.04
# Variable: freq_pitch_R              Importance: 0.04
# Variable: freq_pitch_P              Importance: 0.04
# Variable: num_pics                  Importance: 0.03
# Variable: num_of_sent_risk          Importance: 0.03
# ...

# %%
[print('Variable: {:25} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: goal                      Importance: 0.15
# Variable: num_of_words_perks        Importance: 0.09
# Variable: num_perks                 Importance: 0.08
# Variable: num_of_words_about        Importance: 0.06
# Variable: num_links                 Importance: 0.05
# Variable: num_of_sent_perks         Importance: 0.05
# Variable: num_of_words_risk         Importance: 0.05
# Variable: code                      Importance: 0.04
# Variable: num_of_sent_about         Importance: 0.04
# Variable: freq_bold_A               Importance: 0.04
# Variable: num_of_exclamation_A      Importance: 0.04
# Variable: num_of_exclamation_R      Importance: 0.04
# Variable: num_of_exclamation_P      Importance: 0.04
# Variable: freq_pitch_A              Importance: 0.04
# Variable: freq_pitch_R              Importance: 0.04
# Variable: freq_pitch_P              Importance: 0.04
# Variable: num_pics                  Importance: 0.03
# Variable: num_of_sent_risk          Importance: 0.03
# ...

# %%
plt.style.use('fivethirtyeight')
x_values = list(range(len(importances)))
plt.bar(x_values, importances, orientation = 'vertical')
plt.xticks(x_values, feature_list, rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
features["goal"].hist()

# %%
features_G=features[features["goal"]<10000]

# %%
len(features_G)
# Out:
# 33823

# %%
features_G["goal"].hist(bins=40)

# %%
FFG=features_founded[features_founded["goal"]<10000]
FUFG=features_UNfounded[features_UNfounded["goal"]<10000]

# %%
FFG["goal"].hist(bins=40)

# %%
FUFG["goal"].hist(bins=40)

# %%
features_G.keys()
# Out:
# Index(['goal', 'founded_bool', 'code', 'num_videos', 'num_pics', 'num_perks',
#        'num_links', 'num_of_sent_about', 'num_of_sent_risk',
#        'num_of_sent_perks', 'num_of_words_about', 'num_of_words_risk',
#        'num_of_words_perks', 'freq_bold_A', 'freq_italic_A',
#        'num_of_exclamation_A', 'num_of_exclamation_R', 'num_of_exclamation_P',
#        'bool_A', 'bool_P', 'freq_pitch_A', 'freq_pitch_R', 'freq_pitch_P'],
#       dtype='object')

# %%
len(FFG)
# Out:
# 20993

# %%
len(FUFG)
# Out:
# 12830

# %%
data=features_G.drop(columns=["founded_bool","goal","num_of_sent_perks"])
target=features_G["founded_bool"]

# %%
clf1 = RandomForestClassifier(
    n_estimators=50,
    criterion='gini',
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0.0,
    max_features='auto',
    max_leaf_nodes=None,
    min_impurity_decrease=0.0,
    min_impurity_split=None,
    bootstrap=False,
    oob_score=False,
    n_jobs=-1,
    random_state=0,
    verbose=0,
    warm_start=False,
    class_weight='balanced'
)

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.25, random_state=0)

# %%
clf1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=10, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=-1, oob_score=False, random_state=0,
#             verbose=0, warm_start=False)

# %%
predictions = clf1.predict(x_test)

# %%
clf1.score(x_test,y_test)
# Out:
# 0.7334437086092715

# %%
clf1.score(x_train,y_train)
# Out:
# 0.8180707218039185

# %%
clf1.feature_importances_
# Out:
# array([0.05, 0.  , 0.04, 0.18, 0.04, 0.04, 0.03, 0.06, 0.09, 0.1 , 0.05,
#        0.05, 0.05, 0.1 , 0.03, 0.  , 0.  , 0.03, 0.03, 0.03])

# %%
importances = list(clf1.feature_importances_)
feature_list = list(x_test.columns)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:25} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: num_perks                 Importance: 0.18
# Variable: num_of_words_perks        Importance: 0.1
# Variable: num_of_exclamation_R      Importance: 0.1
# Variable: num_of_words_risk         Importance: 0.09
# Variable: num_of_words_about        Importance: 0.06
# Variable: code                      Importance: 0.05
# Variable: freq_bold_A               Importance: 0.05
# Variable: freq_italic_A             Importance: 0.05
# Variable: num_of_exclamation_A      Importance: 0.05
# Variable: num_pics                  Importance: 0.04
# Variable: num_links                 Importance: 0.04
# Variable: num_of_sent_about         Importance: 0.04
# Variable: num_of_sent_risk          Importance: 0.03
# Variable: num_of_exclamation_P      Importance: 0.03
# Variable: freq_pitch_A              Importance: 0.03
# Variable: freq_pitch_R              Importance: 0.03
# Variable: freq_pitch_P              Importance: 0.03
# Variable: num_videos                Importance: 0.0
# ...

# %%
freq_pr=(features_G["num_of_words_perks"]/features_G["num_perks"])

# %%
freq_pr[freq_pr<150].hist()

# %%
len(freq_pr[freq_pr<150])
# Out:
# 33782

# %%
len(features_G)
# Out:
# 33823

# %%
features_UNfounded["num_perks"].mean()
# Out:
# 6.254524533675448

# %%
features_founded["num_perks"].mean()
# Out:
# 9.920289035874061

# %%
wppU=features_UNfounded["num_of_words_perks"]/features_UNfounded["num_perks"]
wppF=features_founded["num_of_words_perks"]/features_founded["num_perks"]

# %%
wppF.mean()
# Out:
# 33.903372373240906

# %%
wppU.mean()
# Out:
# 29.105705422580954

# %%
features_UNfounded["num_of_exclamation_A"].mean()
# Out:
# 2.625200293902321

# %%
features_founded["num_of_exclamation_A"].mean()
# Out:
# 5.526057412853256

# %%
features_UNfounded["freq_pitch_P"].mean()
# Out:
# 8.480714362015135

# %%
features_founded["freq_pitch_P"].mean()
# Out:
# 7.912265731022915

# %%
features_UNfounded["num_pics"].mean()
# Out:
# 3.3628792828072607

# %%
features_founded["num_pics"].mean()
# Out:
# 6.31749889224015

# %%
features_founded["num_of_words_about"].mean()
# Out:
# 600.1650685311087
